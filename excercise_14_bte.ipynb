# %% [markdown]
# <a href="https://colab.research.google.com/github/idh71/pandas-workout/blob/main/excercise_14_bte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
s = pd.read_csv("/content/nyc-temps.txt").squeeze()

# %%
df  = pd.DataFrame({"temp": s,
                   "hour": [0, 3, 6, 9, 12, 15, 18, 21] * 91})

# %%
# # get the original mean and median
# real_mean_temp = df.temp.mean()
# real_mean_temp
# Out:
# -1.0508241758241759

# %%
# real_median_temp = df.temp.median()
# real_median_temp
# Out:
# 0.0

# %%
df.head(20)
# Out:
#     temp  hour
# 0     -1     0
# 1     -1     3
# 2     -1     6
# 3     -1     9
# 4     -1    12
# 5     -1    15
# 6     -1    18
# 7      1    21
# 8      1     0
# 9      1     3
# 10     1     6
# 11     1     9
# 12     1    12
# 13     1    15
# 14     1    18
# 15     1    21
# 16     1     0
# 17     1     3
# 18     1     6
# 19     1     9

# %%
df.temp.describe()
# Out:
# count    728.000000
# mean      -1.050824
# std        5.026357
# min      -14.000000
# 25%       -4.000000
# 50%        0.000000
# 75%        2.000000
# max       12.000000
# Name: temp, dtype: float64

# %%
# # set all the odd temperatures to the mean of all temperatures
# df.loc[(df.temp % 2 == 1), 'temp'] = df.temp.mean()

# %%
# # set the even temps at hour 9 and 18 to 3
# df.loc[(df.hour.isin([9, 18])) & (df.temp % 2 == 0), 'temp'] = 3

# %%
# if the hour is odd, set the temp to 5
df.loc[(df.hour % 2 == 1), 'temp'] = 5

# %%
df.head(20)
# Out:
#     temp  hour
# 0     -1     0
# 1      5     3
# 2     -1     6
# 3      5     9
# 4     -1    12
# 5      5    15
# 6     -1    18
# 7      5    21
# 8      1     0
# 9      5     3
# 10     1     6
# 11     5     9
# 12     1    12
# 13     5    15
# 14     1    18
# 15     5    21
# 16     1     0
# 17     5     3
# 18     1     6
# 19     5     9
