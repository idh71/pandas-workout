# %%
import pandas as pd

# %%
s = pd.read_csv('./pandas-workout-data/nyc-temps.txt').squeeze('columns')

df = pd.DataFrame({'temp': s,
                  'hour': [0, 3, 6, 9, 12, 15, 18, 21] * 91
                  })

# %%
# set all the odd temps to the mean

df.loc[df['temp'] % 2 != 0, 'temp'] = df['temp'].mean()

# %%
df.head(5)
# Out:
#        temp  hour
# 0 -1.050824     0
# 1 -1.050824     3
# 2 -1.050824     6
# 3 -1.050824     9
# 4 -1.050824    12

# %%
# just resetting the data
s = pd.read_csv('./pandas-workout-data/nyc-temps.txt').squeeze('columns')

df = pd.DataFrame({'temp': s,
                  'hour': [0, 3, 6, 9, 12, 15, 18, 21] * 91
                  })

# %%
# set the even temperatures at 9 and 18 to 3
df.loc[(df['temp'] % 2 == 0) & (df['hour'] == 9) | (df['hour'] == 18 ), 'temp'] = 3

# %%
df.head(100)
# Out:
#         temp  hour
# 0  -1.050824     0
# 1  -1.050824     3
# 2  -1.050824     6
# 3  -1.050824     9
# 4  -1.050824    12
# ..       ...   ...
# 95  2.000000    21
# 96  2.000000     0
# 97  2.000000     3
# 98  2.000000     6
# 99  3.000000     9
#
# [100 rows x 2 columns]

# %%
#resetting
s = pd.read_csv('./pandas-workout-data/nyc-temps.txt').squeeze('columns')

df = pd.DataFrame({'temp': s,
                  'hour': [0, 3, 6, 9, 12, 15, 18, 21] * 91
                  })

# %%
# if the hour is odd, set temp to 5
df.loc[df['hour'] % 2 == 1, 'temp']  = 5

# %%
df.head(30)
# Out:
#     temp  hour
# 0     -1     0
# 1      5     3
# 2     -1     6
# 3      5     9
# 4     -1    12
# 5      5    15
# 6     -1    18
# 7      5    21
# 8      1     0
# 9      5     3
# 10     1     6
# 11     5     9
# 12     1    12
# 13     5    15
# 14     1    18
# 15     5    21
# 16     1     0
# 17     5     3
# 18     1     6
# 19     5     9
# 20     1    12
# 21     5    15
# 22     1    18
# 23     5    21
# 24     5     0
# 25     5     3
# 26     5     6
# 27     5     9
# 28     5    12
# 29     5    15
